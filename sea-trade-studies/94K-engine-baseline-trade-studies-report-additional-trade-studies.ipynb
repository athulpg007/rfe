# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

# %%
# Baseline engine design:
Engine drive: s (sinusoidal)
Compression space dead volume: 25e-6
Compression space swept volume: 174e-6
Expansion space dead volume: 25e-6
Expansion space swept volume: 308e-6
Phase angle: 90
Cooler type: a (annulus)
Annulus outer dia: 12.22e-02
Annulus inner dia: 11.68e-02
Annulus length: 7.62e-02
Regenerator type: a (annulus)
Housing external dia: 12.22e-02
Housing internal dia: 12.22e-02
Matrix internal dia:  11.68e-02
Regenerator length: 10.16e-02
Regenerator type: m (mesh)
Porosity: 0.80
Wire diameter: 0.09e-3
Heater type: a (annulus)
Annulus outer dia: 12.22e-02
Annulus inner dia: 11.68e-02
Annulus length: 12.7e-02
Gas: he
Operating pressure: 10e5
Coold-side temperature: 273
Hot-side temperature: 900
Operating Frequency: 10

# %%
from scipy import interpolate

# %%
output_file1 = 'data\output-1D-sweep-gamma-baseline-report-w5'
param_arr1  = np.loadtxt(output_file1+'-param.dat')
powero_arr1 = np.loadtxt(output_file1+'-pow.dat')
heatin_arr1 = np.loadtxt(output_file1+'-qin.dat')
effact_arr1 = np.loadtxt(output_file1+'-eff.dat')

fig = plt.figure(figsize=(8,6))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(param_arr1, effact_arr1, color='r', marker='s', mfc='none', 
          markeredgewidth=3, markersize=6, linestyle='solid', label=r'Efficiency')
         
plt.xlabel('Phase angle, deg.',fontsize=16)
plt.ylabel('Thermal Efficiency', fontsize=16, color='red')

plt.title(r'$T_C=273 K, T_H=1300K, 10-bar $'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='r')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('r')
ax.spines['left'].set_linewidth(2)
ax.legend(loc='lower center', fontsize=16)
ax.set_ylim([0,1.1*max(effact_arr1)])

ax2 = ax.twinx()
ax2.plot(param_arr1, powero_arr1, color='b', marker='o', mfc='none', 
         markeredgewidth=3, markersize=6, linestyle='solid', label=r'Power')

ax2.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.xaxis.set_tick_params(length=5, width=2)
ax2.yaxis.set_tick_params(length=5, width=2)

ax2.tick_params(direction='in')
#ax2.yaxis.set_ticks_position('both')
ax2.xaxis.set_ticks_position('both')
ax2.tick_params(axis='x',labelsize=16)
ax2.tick_params(axis='y',labelsize=16, colors='b')

ax2.set_xlabel('Expansion Phase Angle Advance',fontsize=16)
ax2.set_ylabel('Output power, W', fontsize=16, color='b')
ax2.spines['right'].set_color('b')
ax2.spines['right'].set_linewidth(2)
ax2.legend(loc='upper right', fontsize=16)
ax2.set_ylim([0,1.1*max( powero_arr1)])

plt.savefig('plots/gamma-baseline-report-w5.png', dpi=300, bbox_inches='tight')
plt.savefig('plots/gamma-baseline-report-w5.pdf', dpi=300,bbox_inches='tight')
plt.savefig('plots/gamma-baseline-report-w5.eps', dpi=300,bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
output_file1 = 'data\output-1D-sweep-gamma-baseline-report-w12'
param_arr1  = np.loadtxt(output_file1+'-param.dat')
powero_arr1 = np.loadtxt(output_file1+'-pow.dat')
heatin_arr1 = np.loadtxt(output_file1+'-qin.dat')
effact_arr1 = np.loadtxt(output_file1+'-eff.dat')

fig = plt.figure(figsize=(8,6))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(param_arr1, effact_arr1, color='r', marker='s', mfc='none', 
          markeredgewidth=3, markersize=6, linestyle='solid', label=r'Efficiency')
         
plt.xlabel('Frequency, Hz',fontsize=16)
plt.ylabel('Thermal Efficiency', fontsize=16, color='red')

plt.title(r'$T_C=273 K, T_H=1300K, 10-bar $'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='r')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('r')
ax.spines['left'].set_linewidth(2)
ax.legend(loc='lower center', fontsize=16)
ax.set_ylim([0,1.1*max(effact_arr1)])

ax2 = ax.twinx()
ax2.plot(param_arr1, powero_arr1, color='b', marker='o', mfc='none', 
         markeredgewidth=3, markersize=6, linestyle='solid', label=r'Power')

ax2.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.xaxis.set_tick_params(length=5, width=2)
ax2.yaxis.set_tick_params(length=5, width=2)

ax2.tick_params(direction='in')
#ax2.yaxis.set_ticks_position('both')
ax2.xaxis.set_ticks_position('both')
ax2.tick_params(axis='x',labelsize=16)
ax2.tick_params(axis='y',labelsize=16, colors='b')

ax2.set_xlabel('Expansion Phase Angle Advance',fontsize=16)
ax2.set_ylabel('Output power, W', fontsize=16, color='b')
ax2.spines['right'].set_color('b')
ax2.spines['right'].set_linewidth(2)
ax2.legend(loc='upper right', fontsize=16)
ax2.set_ylim([0,1.1*max( powero_arr1)])

plt.savefig('plots/gamma-stirling-baseline-report-w12.png', dpi=300, bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-w12.pdf', dpi=300,bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-w12.eps', dpi=300,bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
output_file1 = 'data/output-2D-sweep-gamma-baseline-report-w20'

param1_arr  = np.loadtxt(output_file1+'-param1.dat')
param2_arr  = np.loadtxt(output_file1+'-param2.dat')

powero_arr1 = np.loadtxt(output_file1+'-pow.dat')
heatin_arr1 = np.loadtxt(output_file1+'-qin.dat')
effact_arr1 = np.loadtxt(output_file1+'-eff.dat')

p1 = interpolate.interp2d(param1_arr, param2_arr, powero_arr1, kind='cubic')
q1 = interpolate.interp2d(param1_arr, param2_arr, heatin_arr1, kind='cubic')
e1 = interpolate.interp2d(param1_arr, param2_arr, effact_arr1, kind='cubic')

x_new =  np.linspace( param1_arr[0],  param1_arr[-1],  100)
y_new =  np.linspace( param2_arr[0],  param2_arr[-1],  100)

p1_new =  np.zeros((len(x_new),len(y_new)))
q1_new =  np.zeros((len(x_new),len(y_new)))
e1_new =  np.zeros((len(x_new),len(y_new)))

for i in range(0,len(x_new)):
    for j in range(0,len(y_new)):

        p1_new[i,j] = p1(x_new[i],y_new[j])
        q1_new[i,j] = q1(x_new[i],y_new[j])
        e1_new[i,j] = e1(x_new[i],y_new[j])
           
P1 = p1_new
Q1 = q1_new
E1 = e1_new

X, Y = np.meshgrid(x_new, y_new)

fig = plt.figure()

fig.set_size_inches([16,6])
plt.subplot(121)
plt.ion()
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)
plt.xlabel('Compression space, cc',fontsize=16)
plt.ylabel('Expansion space, cc', fontsize=16, color='k')

plt.title(r'$T_C=273 K, T_H=1300K, 10-bar $'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='k')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('k')
ax.spines['left'].set_linewidth(2)
#ax.legend(loc='lower center', fontsize=16)

plt.contourf(X/1e-6, Y/1e-6, E1, 100, cmap='jet')
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=16)
cbar.set_label(r'Efficiency', labelpad=-27, y=1.07, rotation=0, fontsize=16)
cbar.ax.tick_params(axis='y', direction='in')

CS1 = plt.contour(X/1e-6, Y/1e-6, E1, levels=20)
ax.clabel(CS1, CS1.levels, inline=True, colors = 'k', fontsize=12)

plt.subplot(122)
plt.xlabel('Compression space, cc',fontsize=16)
plt.ylabel('Expansion space, cc', fontsize=16, color='k')

plt.title(r'$T_C=273 K, T_H=1300K, 10-bar $'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='k')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('k')
ax.spines['left'].set_linewidth(2)
#ax.legend(loc='lower center', fontsize=16)

plt.contourf(X/1e-6, Y/1e-6, P1, 100, cmap='jet')
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=16)
cbar.set_label(r'Power, W', labelpad=-27, y=1.07, rotation=0, fontsize=16)
cbar.ax.tick_params(axis='y', direction='in')

CS2 = plt.contour(X/1e-6, Y/1e-6, P1, levels=20)
ax.clabel(CS2, CS2.levels, inline=True, fmt= "%3d", colors = 'k', fontsize=12)

plt.savefig('plots/gamma-baseline-report-w20.png', dpi=300, bbox_inches='tight')
plt.savefig('plots/gamma-baseline-report-w20.pdf', dpi=300,bbox_inches='tight')
plt.savefig('plots/gamma-baseline-report-w20.eps', dpi=300,bbox_inches='tight')

# %%
output_file1 = 'data\output-1D-sweep-gamma-baseline-report-w15'
param_arr1  = np.loadtxt(output_file1+'-param.dat')
powero_arr1 = np.loadtxt(output_file1+'-pow.dat')
heatin_arr1 = np.loadtxt(output_file1+'-qin.dat')
effact_arr1 = np.loadtxt(output_file1+'-eff.dat')

fig = plt.figure(figsize=(8,6))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(param_arr1/1e5, effact_arr1, color='r', marker='s', mfc='none', 
          markeredgewidth=3, markersize=6, linestyle='solid', label=r'Efficiency')
         
plt.xlabel('Operating pressure, bar',fontsize=16)
plt.ylabel('Thermal Efficiency', fontsize=16, color='red')

plt.title(r'$T_C=273K, T_H=1300K$'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='r')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('r')
ax.spines['left'].set_linewidth(2)
ax.legend(loc='lower center', fontsize=16)
ax.set_ylim([0,1.1*max(effact_arr1)])

ax2 = ax.twinx()
ax2.plot(param_arr1/1e5, powero_arr1, color='b', marker='o', mfc='none', 
         markeredgewidth=3, markersize=6, linestyle='solid', label=r'Power')

ax2.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.xaxis.set_tick_params(length=5, width=2)
ax2.yaxis.set_tick_params(length=5, width=2)

ax2.tick_params(direction='in')
#ax2.yaxis.set_ticks_position('both')
ax2.xaxis.set_ticks_position('both')
ax2.tick_params(axis='x',labelsize=16)
ax2.tick_params(axis='y',labelsize=16, colors='b')

ax2.set_xlabel('Expansion Phase Angle Advance',fontsize=16)
ax2.set_ylabel('Output power, W', fontsize=16, color='b')
ax2.spines['right'].set_color('b')
ax2.spines['right'].set_linewidth(2)
ax2.legend(loc='upper right', fontsize=16)
ax2.set_ylim([0,1.1*max( powero_arr1)])

plt.savefig('plots/gamma-stirling-baseline-report-w15.png', dpi=300, bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-w15.pdf', dpi=300,bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-w15.eps', dpi=300,bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
output_file1 = 'data\output-1D-sweep-gamma-baseline-report-w10'
param_arr1  = np.loadtxt(output_file1+'-param.dat')
powero_arr1 = np.loadtxt(output_file1+'-pow.dat')
heatin_arr1 = np.loadtxt(output_file1+'-qin.dat')
effact_arr1 = np.loadtxt(output_file1+'-eff.dat')

fig = plt.figure(figsize=(8,6))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(param_arr1, effact_arr1, color='r', marker='s', mfc='none', 
          markeredgewidth=3, markersize=6, linestyle='solid', label=r'Efficiency')
         
plt.xlabel('Cold-side temperature, K',fontsize=16)
plt.ylabel('Thermal Efficiency', fontsize=16, color='red')

plt.title(r'$T_H=1300K, 10-bar $'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='r')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('r')
ax.spines['left'].set_linewidth(2)
ax.legend(loc='lower center', fontsize=16)
ax.set_ylim([0,1.1*max(effact_arr1)])

ax2 = ax.twinx()
ax2.plot(param_arr1, powero_arr1, color='b', marker='o', mfc='none', 
         markeredgewidth=3, markersize=6, linestyle='solid', label=r'Power')

ax2.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.xaxis.set_tick_params(length=5, width=2)
ax2.yaxis.set_tick_params(length=5, width=2)

ax2.tick_params(direction='in')
#ax2.yaxis.set_ticks_position('both')
ax2.xaxis.set_ticks_position('both')
ax2.tick_params(axis='x',labelsize=16)
ax2.tick_params(axis='y',labelsize=16, colors='b')

ax2.set_xlabel('Expansion Phase Angle Advance',fontsize=16)
ax2.set_ylabel('Output power, W', fontsize=16, color='b')
ax2.spines['right'].set_color('b')
ax2.spines['right'].set_linewidth(2)
ax2.legend(loc='upper right', fontsize=16)
ax2.set_ylim([0,1.1*max( powero_arr1)])

plt.savefig('plots/gamma-stirling-baseline-report-w10.png', dpi=300, bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-w10.pdf', dpi=300,bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-w10.eps', dpi=300,bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
output_file1 = 'data\output-1D-sweep-gamma-baseline-report-x5'
param_arr1  = np.loadtxt(output_file1+'-param.dat')
powero_arr1 = np.loadtxt(output_file1+'-pow.dat')
heatin_arr1 = np.loadtxt(output_file1+'-qin.dat')
effact_arr1 = np.loadtxt(output_file1+'-eff.dat')

fig = plt.figure(figsize=(8,6))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(param_arr1, effact_arr1, color='r', marker='s', mfc='none', 
          markeredgewidth=3, markersize=6, linestyle='solid', label=r'Efficiency')
         
plt.xlabel('Phase angle, deg.',fontsize=16)
plt.ylabel('Thermal Efficiency', fontsize=16, color='red')

plt.title(r'$T_C=90 K, T_H=1300K, 10-bar $'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='r')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('r')
ax.spines['left'].set_linewidth(2)
ax.legend(loc='lower center', fontsize=16)
ax.set_ylim([0,1.1*max(effact_arr1)])

ax2 = ax.twinx()
ax2.plot(param_arr1, powero_arr1, color='b', marker='o', mfc='none', 
         markeredgewidth=3, markersize=6, linestyle='solid', label=r'Power')

ax2.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.xaxis.set_tick_params(length=5, width=2)
ax2.yaxis.set_tick_params(length=5, width=2)

ax2.tick_params(direction='in')
#ax2.yaxis.set_ticks_position('both')
ax2.xaxis.set_ticks_position('both')
ax2.tick_params(axis='x',labelsize=16)
ax2.tick_params(axis='y',labelsize=16, colors='b')

ax2.set_xlabel('Expansion Phase Angle Advance',fontsize=16)
ax2.set_ylabel('Output power, W', fontsize=16, color='b')
ax2.spines['right'].set_color('b')
ax2.spines['right'].set_linewidth(2)
ax2.legend(loc='upper right', fontsize=16)
ax2.set_ylim([0,1.1*max( powero_arr1)])

plt.savefig('plots/gamma-baseline-report-x5.png', dpi=300, bbox_inches='tight')
plt.savefig('plots/gamma-baseline-report-x5.pdf', dpi=300,bbox_inches='tight')
plt.savefig('plots/gamma-baseline-report-x5.eps', dpi=300,bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
output_file1 = 'data\output-1D-sweep-gamma-baseline-report-x12'
param_arr1  = np.loadtxt(output_file1+'-param.dat')
powero_arr1 = np.loadtxt(output_file1+'-pow.dat')
heatin_arr1 = np.loadtxt(output_file1+'-qin.dat')
effact_arr1 = np.loadtxt(output_file1+'-eff.dat')

fig = plt.figure(figsize=(8,6))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(param_arr1, effact_arr1, color='r', marker='s', mfc='none', 
          markeredgewidth=3, markersize=6, linestyle='solid', label=r'Efficiency')
         
plt.xlabel('Frequency, Hz',fontsize=16)
plt.ylabel('Thermal Efficiency', fontsize=16, color='red')

plt.title(r'$T_C=90 K, T_H=1300K, 10-bar $'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='r')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('r')
ax.spines['left'].set_linewidth(2)
ax.legend(loc='lower center', fontsize=16)
ax.set_ylim([0,1.1*max(effact_arr1)])

ax2 = ax.twinx()
ax2.plot(param_arr1, powero_arr1, color='b', marker='o', mfc='none', 
         markeredgewidth=3, markersize=6, linestyle='solid', label=r'Power')

ax2.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.xaxis.set_tick_params(length=5, width=2)
ax2.yaxis.set_tick_params(length=5, width=2)

ax2.tick_params(direction='in')
#ax2.yaxis.set_ticks_position('both')
ax2.xaxis.set_ticks_position('both')
ax2.tick_params(axis='x',labelsize=16)
ax2.tick_params(axis='y',labelsize=16, colors='b')

ax2.set_xlabel('Expansion Phase Angle Advance',fontsize=16)
ax2.set_ylabel('Output power, W', fontsize=16, color='b')
ax2.spines['right'].set_color('b')
ax2.spines['right'].set_linewidth(2)
ax2.legend(loc='upper right', fontsize=16)
ax2.set_ylim([0,1.1*max( powero_arr1)])

plt.savefig('plots/gamma-stirling-baseline-report-x12.png', dpi=300, bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-x12.pdf', dpi=300,bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-x12.eps', dpi=300,bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
from scipy import interpolate

# %%
output_file1 = 'data/output-2D-sweep-gamma-baseline-report-x20'

param1_arr  = np.loadtxt(output_file1+'-param1.dat')
param2_arr  = np.loadtxt(output_file1+'-param2.dat')

powero_arr1 = np.loadtxt(output_file1+'-pow.dat')
heatin_arr1 = np.loadtxt(output_file1+'-qin.dat')
effact_arr1 = np.loadtxt(output_file1+'-eff.dat')

p1 = interpolate.interp2d(param1_arr, param2_arr, powero_arr1, kind='cubic')
q1 = interpolate.interp2d(param1_arr, param2_arr, heatin_arr1, kind='cubic')
e1 = interpolate.interp2d(param1_arr, param2_arr, effact_arr1, kind='cubic')

x_new =  np.linspace( param1_arr[0],  param1_arr[-1],  100)
y_new =  np.linspace( param2_arr[0],  param2_arr[-1],  100)

p1_new =  np.zeros((len(x_new),len(y_new)))
q1_new =  np.zeros((len(x_new),len(y_new)))
e1_new =  np.zeros((len(x_new),len(y_new)))

for i in range(0,len(x_new)):
    for j in range(0,len(y_new)):

        p1_new[i,j] = p1(x_new[i],y_new[j])
        q1_new[i,j] = q1(x_new[i],y_new[j])
        e1_new[i,j] = e1(x_new[i],y_new[j])
           
P1 = p1_new
Q1 = q1_new
E1 = e1_new

X, Y = np.meshgrid(x_new, y_new)

fig = plt.figure()

fig.set_size_inches([16,6])
plt.subplot(121)
plt.ion()
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)
plt.xlabel('Compression space, cc',fontsize=16)
plt.ylabel('Expansion space, cc', fontsize=16, color='k')

plt.title(r'$T_C=90 K, T_H=1300K, 10-bar $'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='k')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('k')
ax.spines['left'].set_linewidth(2)
#ax.legend(loc='lower center', fontsize=16)

plt.contourf(X/1e-6, Y/1e-6, E1, 100, cmap='jet')
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=16)
cbar.set_label(r'Efficiency', labelpad=-27, y=1.07, rotation=0, fontsize=16)
cbar.ax.tick_params(axis='y', direction='in')

CS1 = plt.contour(X/1e-6, Y/1e-6, E1, levels=20)
ax.clabel(CS1, CS1.levels, inline=True, colors = 'k', fontsize=12)

plt.subplot(122)
plt.xlabel('Compression space, cc',fontsize=16)
plt.ylabel('Expansion space, cc', fontsize=16, color='k')

plt.title(r'$T_C=90 K, T_H=1300K, 10-bar $'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='k')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('k')
ax.spines['left'].set_linewidth(2)
#ax.legend(loc='lower center', fontsize=16)

plt.contourf(X/1e-6, Y/1e-6, P1, 100, cmap='jet')
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=16)
cbar.set_label(r'Power, W', labelpad=-27, y=1.07, rotation=0, fontsize=16)
cbar.ax.tick_params(axis='y', direction='in')

CS2 = plt.contour(X/1e-6, Y/1e-6, P1, levels=20)
ax.clabel(CS2, CS2.levels, inline=True, fmt= "%3d", colors = 'k', fontsize=12)

plt.savefig('plots/gamma-baseline-report-x20.png', dpi=300, bbox_inches='tight')
plt.savefig('plots/gamma-baseline-report-x20.pdf', dpi=300,bbox_inches='tight')
plt.savefig('plots/gamma-baseline-report-x20.eps', dpi=300,bbox_inches='tight')

# %%
output_file1 = 'data\output-1D-sweep-gamma-baseline-report-x15'
param_arr1  = np.loadtxt(output_file1+'-param.dat')
powero_arr1 = np.loadtxt(output_file1+'-pow.dat')
heatin_arr1 = np.loadtxt(output_file1+'-qin.dat')
effact_arr1 = np.loadtxt(output_file1+'-eff.dat')

fig = plt.figure(figsize=(8,6))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(param_arr1/1e5, effact_arr1, color='r', marker='s', mfc='none', 
          markeredgewidth=3, markersize=6, linestyle='solid', label=r'Efficiency')
         
plt.xlabel('Operating pressure, bar',fontsize=16)
plt.ylabel('Thermal Efficiency', fontsize=16, color='red')

plt.title(r'$T_C=90K, T_H=1300K$'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='r')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('r')
ax.spines['left'].set_linewidth(2)
ax.legend(loc='lower center', fontsize=16)
ax.set_ylim([0,1.1*max(effact_arr1)])

ax2 = ax.twinx()
ax2.plot(param_arr1/1e5, powero_arr1, color='b', marker='o', mfc='none', 
         markeredgewidth=3, markersize=6, linestyle='solid', label=r'Power')

ax2.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.xaxis.set_tick_params(length=5, width=2)
ax2.yaxis.set_tick_params(length=5, width=2)

ax2.tick_params(direction='in')
#ax2.yaxis.set_ticks_position('both')
ax2.xaxis.set_ticks_position('both')
ax2.tick_params(axis='x',labelsize=16)
ax2.tick_params(axis='y',labelsize=16, colors='b')

ax2.set_xlabel('Expansion Phase Angle Advance',fontsize=16)
ax2.set_ylabel('Output power, W', fontsize=16, color='b')
ax2.spines['right'].set_color('b')
ax2.spines['right'].set_linewidth(2)
ax2.legend(loc='upper right', fontsize=16)
ax2.set_ylim([0,1.1*max( powero_arr1)])

plt.savefig('plots/gamma-stirling-baseline-report-x15.png', dpi=300, bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-x15.pdf', dpi=300,bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-x15.eps', dpi=300,bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
output_file1 = 'data\output-1D-sweep-gamma-baseline-report-x11'
param_arr1  = np.loadtxt(output_file1+'-param.dat')
powero_arr1 = np.loadtxt(output_file1+'-pow.dat')
heatin_arr1 = np.loadtxt(output_file1+'-qin.dat')
effact_arr1 = np.loadtxt(output_file1+'-eff.dat')

fig = plt.figure(figsize=(8,6))
plt.rc('font',family='Times New Roman')
params = {'mathtext.default': 'regular' }
plt.rcParams.update(params)

plt.plot(param_arr1, effact_arr1, color='r', marker='s', mfc='none', 
          markeredgewidth=3, markersize=6, linestyle='solid', label=r'Efficiency')
         
plt.xlabel('Hot-side temperature, K',fontsize=16)
plt.ylabel('Thermal Efficiency', fontsize=16, color='red')

plt.title(r'$T_C=90K, 10-bar $'+', He, ' + r'$\gamma$-engine' , fontsize=16)
         
ax = plt.gca()
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(2)

ax.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax.xaxis.set_tick_params(length=5, width=2)
ax.yaxis.set_tick_params(length=5, width=2, colors='r')

ax.tick_params(direction='in')
#ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
ax.tick_params(axis='x',labelsize=16)
ax.tick_params(axis='y',labelsize=16)

ax.spines['left'].set_color('r')
ax.spines['left'].set_linewidth(2)
ax.legend(loc='lower center', fontsize=16)
ax.set_ylim([0,1.1*max(effact_arr1)])

ax2 = ax.twinx()
ax2.plot(param_arr1, powero_arr1, color='b', marker='o', mfc='none', 
         markeredgewidth=3, markersize=6, linestyle='solid', label=r'Power')

ax2.xaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.xaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.yaxis.grid(which='major', color='k', linestyle='dotted', linewidth=0.5)
ax2.yaxis.grid(which='minor', color='k', linestyle='dotted', linewidth=0.5)

ax2.xaxis.set_tick_params(length=5, width=2)
ax2.yaxis.set_tick_params(length=5, width=2)

ax2.tick_params(direction='in')
#ax2.yaxis.set_ticks_position('both')
ax2.xaxis.set_ticks_position('both')
ax2.tick_params(axis='x',labelsize=16)
ax2.tick_params(axis='y',labelsize=16, colors='b')

ax2.set_xlabel('Expansion Phase Angle Advance',fontsize=16)
ax2.set_ylabel('Output power, W', fontsize=16, color='b')
ax2.spines['right'].set_color('b')
ax2.spines['right'].set_linewidth(2)
ax2.legend(loc='upper right', fontsize=16)
ax2.set_ylim([0,1.1*max( powero_arr1)])

plt.savefig('plots/gamma-stirling-baseline-report-x11.png', dpi=300, bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-x11.pdf', dpi=300,bbox_inches='tight')
plt.savefig('plots/gamma-stirling-baseline-report-x11.eps', dpi=300,bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
